# %%
# !pip install pennylane
# !pip install qiskit
# !pip install qiskit-machine-learning
# Out:
# Requirement already satisfied: pennylane in /opt/miniconda3/lib/python3.12/site-packages (0.44.0)
# Requirement already satisfied: scipy in /opt/miniconda3/lib/python3.12/site-packages (from pennylane) (1.14.1)
# Requirement already satisfied: networkx in /opt/miniconda3/lib/python3.12/site-packages (from pennylane) (3.5)
# Requirement already satisfied: rustworkx>=0.14.0 in /opt/miniconda3/lib/python3.12/site-packages (from pennylane) (0.15.1)
# Requirement already satisfied: autograd in /opt/miniconda3/lib/python3.12/site-packages (from pennylane) (1.8.0)
# Requirement already satisfied: appdirs in /opt/miniconda3/lib/python3.12/site-packages (from pennylane) (1.4.4)
# Requirement already satisfied: autoray==0.8.2 in /opt/miniconda3/lib/python3.12/site-packages (from pennylane) (0.8.2)
# Requirement already satisfied: cachetools in /opt/miniconda3/lib/python3.12/site-packages (from pennylane) (6.2.1)
# Requirement already satisfied: pennylane-lightning>=0.44 in /opt/miniconda3/lib/python3.12/site-packages (from pennylane) (0.44.0)
# Requirement already satisfied: requests in /opt/miniconda3/lib/python3.12/site-packages (from pennylane) (2.32.3)
# Requirement already satisfied: tomlkit in /opt/miniconda3/lib/python3.12/site-packages (from pennylane) (0.13.3)
# Requirement already satisfied: typing_extensions in /opt/miniconda3/lib/python3.12/site-packages (from pennylane) (4.14.1)
# Requirement already satisfied: packaging in /opt/miniconda3/lib/python3.12/site-packages (from pennylane) (24.1)
# Requirement already satisfied: diastatic-malt in /opt/miniconda3/lib/python3.12/site-packages (from pennylane) (2.15.2)
# Requirement already satisfied: numpy in /opt/miniconda3/lib/python3.12/site-packages (from pennylane) (2.1.1)
# Requirement already satisfied: scipy-openblas32>=0.3.26 in /opt/miniconda3/lib/python3.12/site-packages (from pennylane-lightning>=0.44->pennylane) (0.3.30.0.4)
# Requirement already satisfied: astunparse in /opt/miniconda3/lib/python3.12/site-packages (from diastatic-malt->pennylane) (1.6.3)
# Requirement already satisfied: gast in /opt/miniconda3/lib/python3.12/site-packages (from diastatic-malt->pennylane) (0.6.0)
# Requirement already satisfied: termcolor in /opt/miniconda3/lib/python3.12/site-packages (from diastatic-malt->pennylane) (3.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/miniconda3/lib/python3.12/site-packages (from requests->pennylane) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/miniconda3/lib/python3.12/site-packages (from requests->pennylane) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/miniconda3/lib/python3.12/site-packages (from requests->pennylane) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/miniconda3/lib/python3.12/site-packages (from requests->pennylane) (2025.7.14)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/miniconda3/lib/python3.12/site-packages (from astunparse->diastatic-malt->pennylane) (0.43.0)
# Requirement already satisfied: six<2.0,>=1.6.1 in /opt/miniconda3/lib/python3.12/site-packages (from astunparse->diastatic-malt->pennylane) (1.16.0)
# Requirement already satisfied: qiskit in /opt/miniconda3/lib/python3.12/site-packages (2.3.0)
# Requirement already satisfied: rustworkx>=0.15.0 in /opt/miniconda3/lib/python3.12/site-packages (from qiskit) (0.15.1)
# Requirement already satisfied: numpy<3,>=1.17 in /opt/miniconda3/lib/python3.12/site-packages (from qiskit) (2.1.1)
# Requirement already satisfied: scipy>=1.5 in /opt/miniconda3/lib/python3.12/site-packages (from qiskit) (1.14.1)
# Requirement already satisfied: dill>=0.3 in /opt/miniconda3/lib/python3.12/site-packages (from qiskit) (0.3.9)
# Requirement already satisfied: stevedore>=3.0.0 in /opt/miniconda3/lib/python3.12/site-packages (from qiskit) (5.3.0)
# Requirement already satisfied: typing-extensions in /opt/miniconda3/lib/python3.12/site-packages (from qiskit) (4.14.1)
# Requirement already satisfied: pbr>=2.0.0 in /opt/miniconda3/lib/python3.12/site-packages (from stevedore>=3.0.0->qiskit) (6.1.0)
# Requirement already satisfied: qiskit-machine-learning in /opt/miniconda3/lib/python3.12/site-packages (0.9.0)
# Requirement already satisfied: qiskit>=2.0 in /opt/miniconda3/lib/python3.12/site-packages (from qiskit-machine-learning) (2.3.0)
# Requirement already satisfied: numpy>=2.0 in /opt/miniconda3/lib/python3.12/site-packages (from qiskit-machine-learning) (2.1.1)
# Requirement already satisfied: scipy>=1.4 in /opt/miniconda3/lib/python3.12/site-packages (from qiskit-machine-learning) (1.14.1)
# Requirement already satisfied: scikit-learn>=1.2 in /opt/miniconda3/lib/python3.12/site-packages (from qiskit-machine-learning) (1.8.0)
# Requirement already satisfied: setuptools>=40.1 in /opt/miniconda3/lib/python3.12/site-packages (from qiskit-machine-learning) (72.1.0)
# Requirement already satisfied: dill>=0.3.4 in /opt/miniconda3/lib/python3.12/site-packages (from qiskit-machine-learning) (0.3.9)
# Requirement already satisfied: rustworkx>=0.15.0 in /opt/miniconda3/lib/python3.12/site-packages (from qiskit>=2.0->qiskit-machine-learning) (0.15.1)
# Requirement already satisfied: stevedore>=3.0.0 in /opt/miniconda3/lib/python3.12/site-packages (from qiskit>=2.0->qiskit-machine-learning) (5.3.0)
# Requirement already satisfied: typing-extensions in /opt/miniconda3/lib/python3.12/site-packages (from qiskit>=2.0->qiskit-machine-learning) (4.14.1)
# Requirement already satisfied: joblib>=1.3.0 in /opt/miniconda3/lib/python3.12/site-packages (from scikit-learn>=1.2->qiskit-machine-learning) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /opt/miniconda3/lib/python3.12/site-packages (from scikit-learn>=1.2->qiskit-machine-learning) (3.6.0)
# Requirement already satisfied: pbr>=2.0.0 in /opt/miniconda3/lib/python3.12/site-packages (from stevedore>=3.0.0->qiskit>=2.0->qiskit-machine-learning) (6.1.0)

# %%
pip install pylatexenc
# Out:
# Requirement already satisfied: pylatexenc in /opt/miniconda3/lib/python3.12/site-packages (2.10)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install dwave-ocean-sdk
# Out:
# Requirement already satisfied: dwave-ocean-sdk in /opt/miniconda3/lib/python3.12/site-packages (9.3.0)
# Requirement already satisfied: dimod==0.12.21 in /opt/miniconda3/lib/python3.12/site-packages (from dwave-ocean-sdk) (0.12.21)
# Requirement already satisfied: dwave-cloud-client==0.14.4 in /opt/miniconda3/lib/python3.12/site-packages (from dwave-ocean-sdk) (0.14.4)
# Requirement already satisfied: dwave-gate==0.3.5 in /opt/miniconda3/lib/python3.12/site-packages (from dwave-ocean-sdk) (0.3.5)
# Requirement already satisfied: dwave-hybrid==0.6.15 in /opt/miniconda3/lib/python3.12/site-packages (from dwave-ocean-sdk) (0.6.15)
# Requirement already satisfied: dwave-inspector==0.5.5 in /opt/miniconda3/lib/python3.12/site-packages (from dwave-ocean-sdk) (0.5.5)
# Requirement already satisfied: dwave-networkx==0.8.18 in /opt/miniconda3/lib/python3.12/site-packages (from dwave-ocean-sdk) (0.8.18)
# Requirement already satisfied: dwave-optimization==0.6.11 in /opt/miniconda3/lib/python3.12/site-packages (from dwave-ocean-sdk) (0.6.11)
# Requirement already satisfied: dwave-preprocessing==0.6.11 in /opt/miniconda3/lib/python3.12/site-packages (from dwave-ocean-sdk) (0.6.11)
# Requirement already satisfied: dwave-samplers==1.7.0 in /opt/miniconda3/lib/python3.12/site-packages (from dwave-ocean-sdk) (1.7.0)
# Requirement already satisfied: dwave-system==1.34.0 in /opt/miniconda3/lib/python3.12/site-packages (from dwave-ocean-sdk) (1.34.0)
# Requirement already satisfied: minorminer==0.2.21 in /opt/miniconda3/lib/python3.12/site-packages (from dwave-ocean-sdk) (0.2.21)
# Requirement already satisfied: penaltymodel==1.3.0 in /opt/miniconda3/lib/python3.12/site-packages (from dwave-ocean-sdk) (1.3.0)
# Requirement already satisfied: numpy>=1.17.3 in /opt/miniconda3/lib/python3.12/site-packages (from dimod==0.12.21->dwave-ocean-sdk) (2.1.1)
# Requirement already satisfied: requests<3,>=2.25 in /opt/miniconda3/lib/python3.12/site-packages (from requests[socks]<3,>=2.25->dwave-cloud-client==0.14.4->dwave-ocean-sdk) (2.32.3)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/miniconda3/lib/python3.12/site-packages (from dwave-cloud-client==0.14.4->dwave-ocean-sdk) (2.2.2)
# Requirement already satisfied: pydantic<3,>=2 in /opt/miniconda3/lib/python3.12/site-packages (from dwave-cloud-client==0.14.4->dwave-ocean-sdk) (2.12.5)
# Requirement already satisfied: homebase<2,>=1.0 in /opt/miniconda3/lib/python3.12/site-packages (from dwave-cloud-client==0.14.4->dwave-ocean-sdk) (1.0.1)
# Requirement already satisfied: click<9,>=8.2 in /opt/miniconda3/lib/python3.12/site-packages (from dwave-cloud-client==0.14.4->dwave-ocean-sdk) (8.2.1)
# Requirement already satisfied: python-dateutil<3,>=2.7 in /opt/miniconda3/lib/python3.12/site-packages (from dwave-cloud-client==0.14.4->dwave-ocean-sdk) (2.9.0.post0)
# Requirement already satisfied: plucky<0.5,>=0.4.3 in /opt/miniconda3/lib/python3.12/site-packages (from dwave-cloud-client==0.14.4->dwave-ocean-sdk) (0.4.3)
# Requirement already satisfied: diskcache<6,>=5.2.1 in /opt/miniconda3/lib/python3.12/site-packages (from dwave-cloud-client==0.14.4->dwave-ocean-sdk) (5.6.3)
# Requirement already satisfied: packaging>=19 in /opt/miniconda3/lib/python3.12/site-packages (from dwave-cloud-client==0.14.4->dwave-ocean-sdk) (24.1)
# Requirement already satisfied: werkzeug<4,>=3.1.0 in /opt/miniconda3/lib/python3.12/site-packages (from dwave-cloud-client==0.14.4->dwave-ocean-sdk) (3.1.3)
# Requirement already satisfied: typing-extensions<5,>=4.5.0 in /opt/miniconda3/lib/python3.12/site-packages (from dwave-cloud-client==0.14.4->dwave-ocean-sdk) (4.14.1)
# Requirement already satisfied: authlib<2,>=1.2 in /opt/miniconda3/lib/python3.12/site-packages (from dwave-cloud-client==0.14.4->dwave-ocean-sdk) (1.6.9)
# Requirement already satisfied: importlib_metadata>=5.0.0 in /opt/miniconda3/lib/python3.12/site-packages (from dwave-cloud-client==0.14.4->dwave-ocean-sdk) (8.7.0)
# Requirement already satisfied: orjson>=3.11 in /opt/miniconda3/lib/python3.12/site-packages (from dwave-cloud-client==0.14.4->dwave-ocean-sdk) (3.11.7)
# Requirement already satisfied: http-sf>=1.0.4 in /opt/miniconda3/lib/python3.12/site-packages (from dwave-cloud-client==0.14.4->dwave-ocean-sdk) (1.1.1)
# Requirement already satisfied: networkx in /opt/miniconda3/lib/python3.12/site-packages (from dwave-hybrid==0.6.15->dwave-ocean-sdk) (3.5)
# Requirement already satisfied: Flask<4,>=2.2 in /opt/miniconda3/lib/python3.12/site-packages (from dwave-inspector==0.5.5->dwave-ocean-sdk) (3.1.2)
# Requirement already satisfied: scipy>=1.7.3 in /opt/miniconda3/lib/python3.12/site-packages (from dwave-system==1.34.0->dwave-ocean-sdk) (1.14.1)
# Requirement already satisfied: fasteners>=0.15 in /opt/miniconda3/lib/python3.12/site-packages (from minorminer==0.2.21->dwave-ocean-sdk) (0.20)
# Requirement already satisfied: cryptography in /opt/miniconda3/lib/python3.12/site-packages (from authlib<2,>=1.2->dwave-cloud-client==0.14.4->dwave-ocean-sdk) (42.0.5)
# Requirement already satisfied: blinker>=1.9.0 in /opt/miniconda3/lib/python3.12/site-packages (from Flask<4,>=2.2->dwave-inspector==0.5.5->dwave-ocean-sdk) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /opt/miniconda3/lib/python3.12/site-packages (from Flask<4,>=2.2->dwave-inspector==0.5.5->dwave-ocean-sdk) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /opt/miniconda3/lib/python3.12/site-packages (from Flask<4,>=2.2->dwave-inspector==0.5.5->dwave-ocean-sdk) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /opt/miniconda3/lib/python3.12/site-packages (from Flask<4,>=2.2->dwave-inspector==0.5.5->dwave-ocean-sdk) (3.0.2)
# Requirement already satisfied: zipp>=3.20 in /opt/miniconda3/lib/python3.12/site-packages (from importlib_metadata>=5.0.0->dwave-cloud-client==0.14.4->dwave-ocean-sdk) (3.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/miniconda3/lib/python3.12/site-packages (from pydantic<3,>=2->dwave-cloud-client==0.14.4->dwave-ocean-sdk) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/miniconda3/lib/python3.12/site-packages (from pydantic<3,>=2->dwave-cloud-client==0.14.4->dwave-ocean-sdk) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/miniconda3/lib/python3.12/site-packages (from pydantic<3,>=2->dwave-cloud-client==0.14.4->dwave-ocean-sdk) (0.4.2)
# Requirement already satisfied: six>=1.5 in /opt/miniconda3/lib/python3.12/site-packages (from python-dateutil<3,>=2.7->dwave-cloud-client==0.14.4->dwave-ocean-sdk) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/miniconda3/lib/python3.12/site-packages (from requests<3,>=2.25->requests[socks]<3,>=2.25->dwave-cloud-client==0.14.4->dwave-ocean-sdk) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/miniconda3/lib/python3.12/site-packages (from requests<3,>=2.25->requests[socks]<3,>=2.25->dwave-cloud-client==0.14.4->dwave-ocean-sdk) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/miniconda3/lib/python3.12/site-packages (from requests<3,>=2.25->requests[socks]<3,>=2.25->dwave-cloud-client==0.14.4->dwave-ocean-sdk) (2025.7.14)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /opt/miniconda3/lib/python3.12/site-packages (from requests[socks]<3,>=2.25->dwave-cloud-client==0.14.4->dwave-ocean-sdk) (1.7.1)
# Requirement already satisfied: cffi>=1.12 in /opt/miniconda3/lib/python3.12/site-packages (from cryptography->authlib<2,>=1.2->dwave-cloud-client==0.14.4->dwave-ocean-sdk) (1.16.0)
# Requirement already satisfied: pycparser in /opt/miniconda3/lib/python3.12/site-packages (from cffi>=1.12->cryptography->authlib<2,>=1.2->dwave-cloud-client==0.14.4->dwave-ocean-sdk) (2.21)
# Note: you may need to restart the kernel to use updated packages.

# %%
from qiskit import *
import pylatexenc
import matplotlib

# %%
qc = QuantumCircuit(3,3)
qc.draw()
# Out:
#
# q_0:
#
# q_1:
#
# q_2:
#
# c: 3/

# %%
qc.draw('mpl')

# %%
qc.measure([0,1,2], [0,1,2])
qc.draw()
# Out:
#      ┌─┐
# q_0: ┤M├──────
#      └╥┘┌─┐
# q_1: ─╫─┤M├───
#       ║ └╥┘┌─┐
# q_2: ─╫──╫─┤M├
#       ║  ║ └╥┘
# c: 3/═╩══╩══╩═
#       0  1  2

# %%
qreg1 = QuantumRegister(size = 2, name = "qrg1")
qreg2 = QuantumRegister(size = 1, name = "qrg2")
creg = ClassicalRegister(1, "oldschool")

# %%
qc1 = QuantumCircuit(qreg1, creg, qreg2)
qc1.draw()
# Out:
#
#      qrg1_0:
#
#      qrg1_1:
#
#        qrg2:
#
# oldschool: 1/

# %%
qc1.draw()
# Out:
#
#      qrg1_0:
#
#      qrg1_1:
#
#        qrg2:
#
# oldschool: 1/

# %%
# QUANTUM GATES
# por defecto todos los qubits se inicializan al estado |0>

# %%
qc.x(0)
# aplicar una puerta X al primer quibit. Indexado habitual en Python (comienza en 0)

# %%
qc.draw()
# Out:
#      ┌─┐┌───┐
# q_0: ┤M├┤ X ├───
#      └╥┘└┬─┬┘
# q_1: ─╫──┤M├────
#       ║  └╥┘ ┌─┐
# q_2: ─╫───╫──┤M├
#       ║   ║  └╥┘
# c: 3/═╩═══╩═══╩═
#       0   1   2

# %%
qc = QuantumCircuit(2,2)
qc.draw()
# Out:
#
# q_0:
#
# q_1:
#
# c: 2/

# %%
qc.x(0)
qc.h(1)
qc.cx(0,1)
qc.measure([0,1],[0,1])
qc.draw()
# Out:
#      ┌───┐     ┌─┐
# q_0: ┤ X ├──■──┤M├───
#      ├───┤┌─┴─┐└╥┘┌─┐
# q_1: ┤ H ├┤ X ├─╫─┤M├
#      └───┘└───┘ ║ └╥┘
# c: 2/═══════════╩══╩═
#                 0  1

# %%
# CUANDO SE EJECUTA UN BLQUE DE CODIGO SIN LA SEMILLA DEL CIRCUITO, SE AÑADE A LO ANTERIOR -> 
# SE PUEDE GENERAR UN CIRCUITO QUE NO ES EL QUE SE BUSCA, MÁS COMPONENTES DE LO NECESARIO

# %%
# from qiskit.providers.aer import AerSimulator YA NO EXISTE EN VERSIONES NUEVAS

# %%
pip install qiskit-aer
# Out:
# Requirement already satisfied: qiskit-aer in /opt/miniconda3/lib/python3.12/site-packages (0.15.1)
# Requirement already satisfied: qiskit>=1.1.0 in /opt/miniconda3/lib/python3.12/site-packages (from qiskit-aer) (2.3.0)
# Requirement already satisfied: numpy>=1.16.3 in /opt/miniconda3/lib/python3.12/site-packages (from qiskit-aer) (2.1.1)
# Requirement already satisfied: scipy>=1.0 in /opt/miniconda3/lib/python3.12/site-packages (from qiskit-aer) (1.14.1)
# Requirement already satisfied: psutil>=5 in /opt/miniconda3/lib/python3.12/site-packages (from qiskit-aer) (6.0.0)
# Requirement already satisfied: rustworkx>=0.15.0 in /opt/miniconda3/lib/python3.12/site-packages (from qiskit>=1.1.0->qiskit-aer) (0.15.1)
# Requirement already satisfied: dill>=0.3 in /opt/miniconda3/lib/python3.12/site-packages (from qiskit>=1.1.0->qiskit-aer) (0.3.9)
# Requirement already satisfied: stevedore>=3.0.0 in /opt/miniconda3/lib/python3.12/site-packages (from qiskit>=1.1.0->qiskit-aer) (5.3.0)
# Requirement already satisfied: typing-extensions in /opt/miniconda3/lib/python3.12/site-packages (from qiskit>=1.1.0->qiskit-aer) (4.14.1)
# Requirement already satisfied: pbr>=2.0.0 in /opt/miniconda3/lib/python3.12/site-packages (from stevedore>=3.0.0->qiskit>=1.1.0->qiskit-aer) (6.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import qiskit
import qiskit_aer

print(qiskit.__version__)
print(qiskit_aer.__version__)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[22], line 2
#       1 import qiskit
# ----> 2 import qiskit_aer
#       4 print(qiskit.__version__)
#       5 print(qiskit_aer.__version__)
#
# File /opt/miniconda3/lib/python3.12/site-packages/qiskit_aer/__init__.py:69
#      65     np.dot(np.zeros(100), np.zeros(100))
#      66 # ... ¯\_(ツ)_/¯
#      67
#      68 # pylint: disable=wrong-import-position
# ---> 69 from qiskit_aer.aerprovider import AerProvider
#      70 from qiskit_aer.jobs import AerJob
#      71 from qiskit_aer.aererror import AerError
#
# File /opt/miniconda3/lib/python3.12/site-packages/qiskit_aer/aerprovider.py:20
#      17 from qiskit.providers import QiskitBackendNotFoundError
#      18 from qiskit.providers.providerutils import filter_backends
# ---> 20 from .backends.aer_simulator import AerSimulator
#      21 from .backends.qasm_simulator import QasmSimulator
#      22 from .backends.statevector_simulator import StatevectorSimulator
#
# File /opt/miniconda3/lib/python3.12/site-packages/qiskit_aer/backends/__init__.py:17
#       1 # This code is part of Qiskit.
#       2 #
#       3 # (C) Copyright IBM 2018, 2019.
#    (...)     10 # copyright notice, and modified files need to carry a notice indicating
#      11 # that they have been altered from the originals.
#      13 """
#      14 Aer Provider Simulator Backends
#      15 """
# ---> 17 from .aer_simulator import AerSimulator
#      18 from .qasm_simulator import QasmSimulator
#      19 from .statevector_simulator import StatevectorSimulator
#
# File /opt/miniconda3/lib/python3.12/site-packages/qiskit_aer/backends/aer_simulator.py:19
#      17 import logging
#      18 from warnings import warn
# ---> 19 from qiskit.providers import convert_to_target
#      20 from qiskit.providers.options import Options
#      21 from qiskit.providers.backend import BackendV2, BackendV1
#
# ImportError: cannot import name 'convert_to_target' from 'qiskit.providers' (/opt/miniconda3/lib/python3.12/site-packages/qiskit/providers/__init__.py)
