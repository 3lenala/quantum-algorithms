# %% [markdown]
# REENTRENAMOS EL MODELO EN ml.ipynb PARA VER COMO AFECTA AL RESULTADO EL CAMBIO DE ARGUMENTOS OPCIONALES EN ALGUNAS FUNCIONES

# %% [markdown]
# 1) CAMBIAMOS EL LEARNING_RATE A 10**(-6)

# %%
import tensorflow as tf
from tensorflow import keras

import numpy as np
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
seed = 128
np.random.seed(seed)

# %%
data, labels = make_classification(n_samples=2500,
                                   n_features=2,n_redundant=0,
                                   weights=[0.2,0.8], class_sep=0.5, 
                                   random_state=seed)
x_tr, x_test, y_tr, y_test = train_test_split(data, labels, train_size=0.8, shuffle=True)
x_val, x_test, y_val, y_test = train_test_split(x_test, y_test, train_size=0.5, shuffle=True)

# %%
tf.random.set_seed(seed=seed)

model = tf.keras.Sequential([
    tf.keras.Input(shape=(2,)),   # define los 2 inputs
    tf.keras.layers.Dense(8, activation='elu'),
    tf.keras.layers.Dense(16, activation='elu'),
    tf.keras.layers.Dense(8, activation='elu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

opt = tf.keras.optimizers.Adam(learning_rate=10**(-6))
lossf = tf.keras.losses.BinaryCrossentropy()
model.compile(optimizer=opt, loss=lossf)

history = model.fit(x_tr, y_tr, validation_data=(x_val,y_val), 
                    epochs=8, batch_size=None)

output = model.predict(x_test)
result = (output > 0.5).astype(float)
print(accuracy_score(result,y_test))
# Out:
# Epoch 1/8
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - loss: 0.7828 - val_loss: 0.7541
# Epoch 2/8
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.7822 - val_loss: 0.7535
# Epoch 3/8
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7817 - val_loss: 0.7530
# Epoch 4/8
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7812 - val_loss: 0.7524
# Epoch 5/8
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.7806 - val_loss: 0.7518
# Epoch 6/8
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.7801 - val_loss: 0.7513
# Epoch 7/8
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.7795 - val_loss: 0.7507
# Epoch 8/8
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.7790 - val_loss: 0.7502
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 0.404

# %% [markdown]
# El resultado es menos preciso cuando se disminuye el tamaño del ratio de aprendizaje sin aumentar el numero de epochs porque el algoritmo no puede dar los suficientes pasos para alcanzar el minimo en los parametros de entrenamiento

# %% [markdown]
# 2) LEARNING_RATE A 10**(-6) Y EPOCHS = 1000

# %%
tf.random.set_seed(seed=seed)

model = tf.keras.Sequential([
    tf.keras.Input(shape=(2,)),   # define los 2 inputs
    tf.keras.layers.Dense(8, activation='elu'),
    tf.keras.layers.Dense(16, activation='elu'),
    tf.keras.layers.Dense(8, activation='elu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

opt = tf.keras.optimizers.Adam(learning_rate=10**(-6))
lossf = tf.keras.losses.BinaryCrossentropy()
model.compile(optimizer=opt, loss=lossf)

history = model.fit(x_tr, y_tr, validation_data=(x_val,y_val), 
                    epochs=1000, batch_size=None)

output = model.predict(x_test)
result = (output > 0.5).astype(float)
print(accuracy_score(result,y_test))
# Out:
# Epoch 1/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - loss: 0.7342 - val_loss: 0.7365
# Epoch 2/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.7338 - val_loss: 0.7361
# Epoch 3/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.7335 - val_loss: 0.7357
# Epoch 4/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.7331 - val_loss: 0.7353
# Epoch 5/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.7327 - val_loss: 0.7349
# Epoch 6/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.7324 - val_loss: 0.7345
# Epoch 7/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.7320 - val_loss: 0.7342
# Epoch 8/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7317 - val_loss: 0.7338
# Epoch 9/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7313 - val_loss: 0.7334
# Epoch 10/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.7309 - val_loss: 0.7330
# Epoch 11/1000
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.7306 - val_loss: 0.7326
# ...
